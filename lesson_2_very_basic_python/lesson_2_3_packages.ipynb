# %% [markdown]
# # Lesson 2.3: Packages
#
# **🎬 Video:** [Lesson 2.3: Packages](#)
#
# ## Overview
#
# In these lessons you will be working with libraries. Libraries are collections of pre-built functions for a particular task. Understanding how to load and use a package is one of the most practical Python skills you can have.
#
# **What you will learn in this lesson:**
# - **Packages** — what they are and why we use them
# - **`import` statement** — how to load a package and give it a nickname
# - **Prefix notation** — how to call a package's functions
#
# **Lesson series:**
# - [2.1 — Variables & Data Types](lesson_2_1_overview_variables.ipynb)
# - [2.2 — Functions & Methods](lesson_2_2_functions_methods.ipynb)
# - **2.3 — Packages** ← you are here
# - [2.4 — Reading Code](lesson_2_4_reading_code.ipynb)

# %% [markdown]
# ---
#
# ## 1 Packages
#
# A **package** is a collection of pre-written functions that other people have built and shared. Instead of writing every tool from scratch, you import a package and use the tools inside it.
#
# The `import` statement loads a package. The `as` keyword gives it a short nickname so you don't have to type the full name each time:
#
# ```python
# import pandas as pd       # data tables — nicknamed "pd"
# import nltk               # natural language processing
# import spacy              # location and entity extraction
# ```
#
# Packages are loaded once at the top of a notebook and then available everywhere below.

# %%
import pandas as pd

# %% [markdown]
# Once a package is imported, you access its functions using the prefix:
#
# ```python
# pd.read_csv("data.csv")       # load a CSV file
# pd.DataFrame(my_list)         # convert a list into a table
# ```
#
# You can also pass keyword arguments (the `name=value` pattern from Part 2) to customize how functions run:
#
# ```python
# df = pd.read_csv("data.csv", encoding="utf-8")
# df.head(10)
# ```
#
# You do not need to memorize which keyword arguments exist — the documentation (or a quick search) will always tell you what options are available for a given function.
#
# **Common mistake: forgetting to run the import cell**
#
# The most frequent error in these lessons is a `NameError` caused by skipping the `import` cell:
#
# ```python
# NameError: name 'pd' is not defined
# ```
#
# This means Python has never heard of `pd` — because the `import pandas as pd` cell was never run. The fix is always the same: scroll up, run the import cell, then re-run the cell that failed. When in doubt, use **Execute Above Cells** to make sure every cell above has been executed in order.
#
# ![Execute Above Cells](../lesson_assets/images/execute-above-cells.png)

# %% [markdown]
# > 💡 **Reflection:** Why might Python ship its core language without data-science tools like pandas built in? What would be the downside of automatically loading every available package every time Python starts?

# %% [markdown]
# ---
#
# ## Lesson Summary
#
# ### Part 1: Packages
# - **Package** — a collection of pre-written functions that can be imported and reused
# - **`import … as …`** — loads a package and assigns it a short nickname (e.g. `import pandas as pd`)
# - **Prefix notation** — call a package's functions using the nickname: `pd.read_csv()`, `pd.DataFrame()`
# - **Common mistake** — a `NameError: name 'pd' is not defined` always means the import cell was never run; use **Execute Above Cells** to fix it
#
# ---
#
# ➡️ **Next:** [Lesson 2.4 — Reading Code](lesson_2_4_reading_code.ipynb)
